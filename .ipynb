# %%
import pandas as pd
url = "https://docs.google.com/spreadsheets/d/18ruTRG07crEe3ddd8zeZud3bdhKKF3w17jjooQMkU7g/export?format=csv"
df = pd.read_csv(url)

df
# Out:
#    person number                       tense        mood termination answer  \
# 0      1ª      S             presente simple  indicativo         -ar     -o
# 1      3ª      S             presente simple  indicativo         -ar     -a
# 2      1ª      P             presente simple  indicativo         -ar  -amos
# 3      3ª      P             presente simple  indicativo         -ar    -am
# 4      1ª      S             presente simple  indicativo         -er     -o
# 5      3ª      S             presente simple  indicativo         -er     -e
# 6      1ª      P             presente simple  indicativo         -er  -emos
# 7      3ª      P             presente simple  indicativo         -er    -em
# 8      1ª      S             presente simple  indicativo         -ir     -o
# 9      3ª      S             presente simple  indicativo         -ir     -e
# 10     1ª      P             presente simple  indicativo         -ir  -imos
# ...
